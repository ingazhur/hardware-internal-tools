# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from util import *
# %matplotlib inline

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="8ylUaecDpmw8Hvr7d41q")
project = rf.workspace().project("resistor-detection-5azes")
model = project.version(5).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# infer on a local image
img_path = "images/tinkercad.png"
confidence = 70
overlap = 80
#print(model.predict(img_path, confidence=confidence, overlap=overlap).json())

# %%
# visualize your prediction
model.predict(img_path, confidence=confidence, overlap=overlap).save("prediction.jpg")

# display prediction.jpg
img = cv2.imread("prediction.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.axis('off')
plt.show()
