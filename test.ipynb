# %%
from preprocessing import *
from util import *

# %%
img_filename = 'images/tinkercad.png'
bounding_box = [[42, 44, 1735, 1128]]
grid_keypoints, rail_keypoints = process_board(img=img_filename, bounding_box=bounding_box)
# Out:
# Total number of keypoints: 376
# /Users/inga/Desktop/hardware-internal-tools/preprocessing.py:183: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   rails = np.array(rails)
# /usr/local/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
img = cv2.imread(img_filename)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
show_points_on_image(img, rail_keypoints)
show_points_on_image(img, grid_keypoints)
